# %%
import numpy as np
import pandas as pd
import datetime
from pylab import rcParams
from sklearn.preprocessing import StandardScaler

from sklearn.metrics import mean_squared_error
from tqdm import tqdm_notebook
from sklearn.preprocessing import StandardScaler
from tensorflow import set_random_seed
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM
from keras.utils import plot_model
import math
from datetime import date

# %%
df = pd.read_csv("df_RNN.csv", index_col=[0])

# %%
df
# Out:
#           date     open     high      low  adj_close**  sentiments
# 99  2019-05-29  1127.52  1129.10  1108.22      1116.46    0.199160
# 98  2019-05-30  1115.54  1123.13  1112.12      1117.95    0.024045
# 97  2019-05-31  1101.29  1109.60  1100.18      1103.63    0.199324
# 96  2019-06-03  1065.50  1065.50  1025.00      1036.23    0.140989
# 95  2019-06-04  1042.90  1056.05  1033.69      1053.05    0.139237
# 94  2019-06-05  1051.54  1053.55  1030.49      1042.22    0.128009
# 93  2019-06-06  1044.99  1047.49  1033.70      1044.34   -0.121932
# 92  2019-06-07  1050.63  1070.92  1048.40      1066.04    0.002834
# 91  2019-06-10  1072.98  1092.66  1072.32      1080.38   -0.116249
# 90  2019-06-11  1093.98  1101.99  1077.60      1078.72    0.173841
# 89  2019-06-12  1078.00  1080.93  1067.54      1077.03    0.158118
# 88  2019-06-13  1083.64  1094.17  1080.15      1088.77    0.145342
# 87  2019-06-14  1086.42  1092.69  1080.17      1085.35    0.193001
# 86  2019-06-17  1086.28  1099.18  1086.28      1092.50    0.167590
# 85  2019-06-18  1109.69  1116.39  1098.99      1103.60    0.181690
# 84  2019-06-19  1105.60  1107.00  1093.48      1102.33    0.195269
# 83  2019-06-20  1119.99  1120.12  1104.74      1111.42    0.163177
# 82  2019-06-21  1109.24  1124.11  1108.08      1121.88    0.189569
# 81  2019-06-24  1119.61  1122.00  1111.01      1115.52    0.029260
# 80  2019-06-25  1112.66  1114.35  1083.80      1086.35   -0.007065
# 79  2019-06-26  1086.50  1092.97  1072.24      1079.80    0.183344
# 78  2019-06-27  1084.00  1087.10  1075.29      1076.01    0.033702
# 77  2019-06-28  1076.39  1081.00  1073.37      1080.91    0.180193
# 76  2019-07-01  1098.00  1107.58  1093.70      1097.95    0.201865
# 75  2019-07-02  1102.24  1111.77  1098.17      1111.25    0.195238
# 74  2019-07-03  1117.41  1126.76  1113.86      1121.58    0.171817
# 73  2019-07-05  1117.80  1132.88  1116.14      1131.59    0.034289
# 72  2019-07-08  1125.17  1125.98  1111.21      1116.35   -0.096034
# 71  2019-07-09  1111.80  1128.03  1107.17      1124.83    0.150651
# 70  2019-07-10  1131.22  1142.05  1130.97      1140.48    0.193030
# ..         ...      ...      ...      ...          ...         ...
# 29  2019-09-06  1208.13  1212.02  1202.52      1204.93    0.074718
# 28  2019-09-09  1204.00  1220.00  1192.62      1204.41    0.174363
# 27  2019-09-10  1195.15  1210.00  1194.58      1206.00    0.051360
# 26  2019-09-11  1203.41  1222.60  1202.20      1220.17   -0.025785
# 25  2019-09-12  1224.30  1241.86  1223.02      1234.25    0.025399
# 24  2019-09-13  1231.35  1240.88  1227.01      1239.56    0.099602
# 23  2019-09-16  1229.52  1239.56  1225.61      1231.30    0.206555
# 22  2019-09-17  1230.40  1235.00  1223.69      1229.15   -0.067362
# 21  2019-09-18  1227.51  1235.61  1216.53      1232.41    0.182087
# 20  2019-09-19  1232.06  1244.44  1232.02      1238.71    0.044522
# 19  2019-09-20  1233.12  1243.32  1223.08      1229.93    0.130114
# 18  2019-09-23  1226.00  1239.09  1224.17      1234.03    0.104840
# 17  2019-09-24  1240.00  1246.74  1210.68      1218.76    0.193752
# 16  2019-09-25  1215.82  1248.30  1210.09      1246.52    0.143535
# 15  2019-09-26  1241.96  1245.00  1232.27      1241.39    0.081002
# 14  2019-09-27  1243.01  1244.02  1214.45      1225.09    0.204399
# 13  2019-09-30  1220.97  1226.00  1212.30      1219.00    0.206465
# 12  2019-10-01  1219.00  1231.23  1203.58      1205.10    0.150039
# 11  2019-10-02  1196.98  1196.98  1171.29      1176.63   -0.018772
# 10  2019-10-03  1180.00  1189.06  1162.43      1187.83    0.193018
# 9   2019-10-04  1191.89  1211.44  1189.17      1209.00    0.139398
# 8   2019-10-07  1204.40  1218.20  1203.75      1207.68    0.188636
# 7   2019-10-08  1197.59  1206.08  1189.01      1189.13    0.162102
# 6   2019-10-09  1199.35  1208.35  1197.63      1202.31    0.193995
# 5   2019-10-10  1198.58  1215.00  1197.34      1208.67    0.198575
# 4   2019-10-11  1222.21  1228.39  1213.74      1215.45    0.148308
# 3   2019-10-14  1212.34  1226.33  1211.76      1217.14   -0.062707
# 2   2019-10-15  1220.40  1247.33  1220.40      1243.01    0.132530
# 1   2019-10-16  1241.17  1254.74  1238.45      1243.64    0.187204
# 0   2019-10-17  1250.93  1263.32  1249.94      1253.07    0.052831
#
# [100 rows x 6 columns]

# %%
test_size = 0.2
N = 9
lstm_units = 128
dropout_prob = 1
optimizer = 'nadam'
epochs = 50
batch_size = 8

# %%
df.loc[:, 'date'] = pd.to_datetime(df['date'],format='%Y-%m-%d')

# %%
df.head()
# Out:
#          date     open     high      low  adj_close**  sentiments
# 99 2019-05-29  1127.52  1129.10  1108.22      1116.46    0.199160
# 98 2019-05-30  1115.54  1123.13  1112.12      1117.95    0.024045
# 97 2019-05-31  1101.29  1109.60  1100.18      1103.63    0.199324
# 96 2019-06-03  1065.50  1065.50  1025.00      1036.23    0.140989
# 95 2019-06-04  1042.90  1056.05  1033.69      1053.05    0.139237

# %%
df.sort_values(by='date', inplace=True, ascending=True)

# %%
df.head()
# Out:
#          date     open     high      low  adj_close**  sentiments
# 99 2019-05-29  1127.52  1129.10  1108.22      1116.46    0.199160
# 98 2019-05-30  1115.54  1123.13  1112.12      1117.95    0.024045
# 97 2019-05-31  1101.29  1109.60  1100.18      1103.63    0.199324
# 96 2019-06-03  1065.50  1065.50  1025.00      1036.23    0.140989
# 95 2019-06-04  1042.90  1056.05  1033.69      1053.05    0.139237

# %%
num_test = int(len(df) * test_size)
num_train = len(df) - num_test

# %%
num_test, num_train
# Out:
# (20, 80)

# %%
train = df[:num_train][['date','open','high','low','adj_close**','sentiments']]

# %%
test = df[num_train:][['date','open','high','low','adj_close**','sentiments']]

# %%
train.shape
# Out:
# (80, 6)

# %%
test.shape
# Out:
# (20, 6)

# %%
train.head()
# Out:
#          date     open     high      low  adj_close**  sentiments
# 99 2019-05-29  1127.52  1129.10  1108.22      1116.46    0.199160
# 98 2019-05-30  1115.54  1123.13  1112.12      1117.95    0.024045
# 97 2019-05-31  1101.29  1109.60  1100.18      1103.63    0.199324
# 96 2019-06-03  1065.50  1065.50  1025.00      1036.23    0.140989
# 95 2019-06-04  1042.90  1056.05  1033.69      1053.05    0.139237

# %%
test.head()
# Out:
#          date     open     high      low  adj_close**  sentiments
# 19 2019-09-20  1233.12  1243.32  1223.08      1229.93    0.130114
# 18 2019-09-23  1226.00  1239.09  1224.17      1234.03    0.104840
# 17 2019-09-24  1240.00  1246.74  1210.68      1218.76    0.193752
# 16 2019-09-25  1215.82  1248.30  1210.09      1246.52    0.143535
# 15 2019-09-26  1241.96  1245.00  1232.27      1241.39    0.081002

# %%
scaler = StandardScaler()
train_scaled = scaler.fit_transform(np.array(train[['open','high','low','adj_close**','sentiments']]))

# %%
train_scaled
# Out:
# array([[-0.43957695, -0.56993947, -0.62502017, -0.638981  ,  0.90654431],
#        [-0.66999938, -0.68031698, -0.55202101, -0.61144986, -0.7716522 ],
#        [-0.94408283, -0.93046904, -0.77551073, -0.87604439,  0.90811093],
#        [-1.63246504, -1.74582052, -2.18270982, -2.12141247,  0.3490626 ],
#        [-2.06715177, -1.9205387 , -2.02005273, -1.81062477,  0.33227166],
#        [-1.90097065, -1.96676044, -2.07994948, -2.01073361,  0.22467657],
#        [-2.02695286, -2.07880194, -2.01986556, -1.9715618 , -2.17061338],
#        [-1.91847352, -1.64561179, -1.7447149 , -1.57060501, -0.97492568],
#        [-1.48859527, -1.24366755, -1.29698675, -1.30564094, -2.11614899],
#        [-1.08468283, -1.07116801, -1.19815712, -1.33631321,  0.66390031],
#        [-1.39204096, -1.46053995, -1.38645751, -1.3675398 ,  0.51322112],
#        [-1.28356162, -1.21574961, -1.1504269 , -1.15061664,  0.39078372],
#        [-1.23009131, -1.24311288, -1.15005255, -1.2138089 ,  0.84751715],
#        [-1.23278406, -1.12312125, -1.03568721, -1.08169641,  0.60399467],
#        [-0.78251785, -0.80493079, -0.79778483, -0.8765987 ,  0.73912078],
#        [-0.86118461, -0.97853965, -0.90091954, -0.90006484,  0.86925286],
#        [-0.58440841, -0.73596796, -0.69015787, -0.73210644,  0.56170653],
#        [-0.79117312, -0.66219806, -0.62764065, -0.53883418,  0.81463008],
#        [-0.59171731, -0.70120921, -0.5727977 , -0.65634963, -0.72167471],
#        [-0.72539309, -0.84264773, -1.08210718, -1.19533163, -1.06979747],
#        [ 0.56116421,  0.4214244 ,  0.56524041,  0.49071937,  0.40695173],
#        [ 0.76388979,  0.87014505,  0.90740055,  0.87597048,  0.64248804],
#        [ 0.86313685,  0.6680636 ,  0.75803305,  0.58476868,  0.75500661],
#        [ 0.82274561,  0.72242037,  0.85761138,  0.74293412,  0.88180979],
#        [ 0.84044082,  0.70411656,  0.69195946,  0.71115322,  0.66562532],
#        [ 0.60809499,  0.63145598,  0.11489178,  0.00458236,  0.24476447],
#        [ 0.13244001,  0.17644918,  0.21241116,  0.32978234,  0.57270483],
#        [ 0.58001346,  0.41550802,  0.37132471,  0.3103812 ,  0.86758375],
#        [ 0.21803098,  0.30494562,  0.29364612,  0.36913893, -1.50163533],
#        [ 0.59136148,  0.6680636 ,  0.7395025 ,  0.77249776,  0.28496155],
#        [ 0.92564711,  0.71317602,  0.78966602,  0.68473072,  0.40983607],
#        [ 0.51269472,  0.49852226,  0.40408074,  0.3205437 ,  0.85508405],
#        [ 0.50653987,  0.43547581,  0.55007905,  0.56111777, -2.2176067 ],
#        [ 0.79158665,  0.98200166,  0.93435409,  1.11488159,  0.86382625],
#        [ 1.11086982,  0.96314319,  1.14006196,  0.99570319, -0.28603144],
#        [ 1.0314337 ,  1.11068298,  0.95475641,  0.98609501,  0.66890631],
#        [ 0.86121346,  0.92579602,  0.99144317,  1.01547387, -0.50988397],
#        [ 1.02008569,  1.15875359,  1.13407229,  1.27729681, -1.24919894],
#        [ 1.4218824 ,  1.51484587,  1.52377547,  1.53745679, -0.75868265],
#        [ 1.55748158,  1.49672695,  1.59845922,  1.6355711 , -0.04756287],
#        [ 1.52228349,  1.47232187,  1.57225439,  1.48294884,  0.97740965],
#        [ 1.53920935,  1.38801342,  1.53631635,  1.4432227 , -1.64765059],
#        [ 1.4836233 ,  1.39929152,  1.40229739,  1.50345861,  0.74292353],
#        [ 1.57113767,  1.5625467 ,  1.69223505,  1.61986542, -0.57541321]])

# %%
train_scaled.shape
# Out:
# (80, 5)

# %%
def get_x_y(data, N, offset):
    # Split data into x (features) and y (target)
    
    x, y = [], []
    for i in range(offset, len(data)):
        x.append(data[i-N:i])
        y.append(data[i,1])
    
    x = np.array(x)
    y = np.array(y)
    
    return x, y

# %%
x_train_scaled, y_train_scaled = get_x_y(train_scaled, N, N)

# %%
x_train_scaled.shape
# Out:
# (71, 9, 5)

# %%
y_train_scaled.shape
# Out:
# (71,)

# %%
y_train_scaled
# Out:
# array([-1.07116801, -1.46053995, -1.21574961, -1.24311288, -1.12312125,
#        -0.80493079, -0.97853965, -0.73596796, -0.66219806, -0.70120921,
#        -0.84264773, -1.23793605, -1.34646469, -1.45924574, -0.9678162 ,
#        -0.89034857, -0.61320302, -0.5000522 , -0.6276242 , -0.58972237,
#        -0.33051086, -0.12676543, -0.23270566, -0.168365  , -0.02489272,
#        -0.02896023, -0.2278986 , -0.16244861, -0.38227921, -0.24084068,
#        -0.2944579 , -0.3369819 ,  1.95284307,  1.61671858,  1.38560989,
#         1.36952472,  1.37155848,  0.86848106,  0.28312895,  0.3703956 ,
#         0.34229278,  0.83353743,  0.8126452 ,  0.46283908,  0.82928503,
#         0.41365915,  0.29422217,  0.4214244 ,  0.87014505,  0.6680636 ,
#         0.72242037,  0.70411656,  0.63145598,  0.17644918,  0.41550802,
#         0.30494562,  0.6680636 ,  0.71317602,  0.49852226,  0.43547581,
#         0.98200166,  0.96314319,  1.11068298,  0.92579602,  1.15875359,
#         1.51484587,  1.49672695,  1.47232187,  1.38801342,  1.39929152,
#         1.5625467 ])

# %%
model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(x_train_scaled.shape[1],5)))
model.add(Dropout(0.5)) # Add dropout with a probability of 0.5
model.add(LSTM(units=50))
model.add(Dropout(1)) # Add dropout with a probability of 0.5
model.add(Dense(1))

model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(x_train_scaled, y_train_scaled, epochs=1, batch_size=1, verbose=2)
# Out:
# Epoch 1/1
#  - 4s - loss: 0.2809

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_21 (LSTM)               (None, 9, 50)             11200
# _________________________________________________________________
# dropout_21 (Dropout)         (None, 9, 50)             0
# _________________________________________________________________
# lstm_22 (LSTM)               (None, 50)                20200
# _________________________________________________________________
# dropout_22 (Dropout)         (None, 50)                0
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 51
# =================================================================
# Total params: 31,451
# Trainable params: 31,451
# Non-trainable params: 0
# _________________________________________________________________

# %%
def get_x_scaled_y(data, N, offset):
    """
    Split data into x (features) and y (target)
    We scale x to have mean 0 and std dev 1, and return this.
    We do not scale y here.
    Inputs
        data     : pandas series to extract x and y
        N
        offset
    Outputs
        x_scaled : features used to predict y. Scaled such that each element has mean 0 and std dev 1
        y        : target values. Not scaled
        mu_list  : list of the means. Same length as x_scaled and y
        std_list : list of the std devs. Same length as x_scaled and y
    """
    
    x_scaled, y, mu_list, std_list = [], [], [], []
    for i in range(offset, len(data)):
        mu_list.append(np.mean(data[i-N:i]))
        std_list.append(np.std(data[i-N:i]))
        x_scaled.append((data[i-N:i] - mu_list[i-offset]) / std_list[i-offset])
        y.append(data[i,1])
    
    x_scaled = np.array(x_scaled)
    y = np.array(y)
    
    return x_scaled, y, mu_list, std_list

# %%
x_test_scaled, y_test, mu_test_list, std_test_list = get_x_scaled_y(np.array(df[['open','high','low','adj_close**','sentiments']]), N, num_train)

# %%
x_test_scaled.shape
# Out:
# (20, 9, 5)

# %%
y_test.shape
# Out:
# (20,)

# %%
y_test
# Out:
# array([1243.32, 1239.09, 1246.74, 1248.3 , 1245.  , 1244.02, 1226.  ,
#        1231.23, 1196.98, 1189.06, 1211.44, 1218.2 , 1206.08, 1208.35,
#        1215.  , 1228.39, 1226.33, 1247.33, 1254.74, 1263.32])

# %%
def train_pred_eval_model(x_train_scaled, \
                          y_train_scaled, \
                          x_cv_scaled, \
                          y_cv, \
                          mu_cv_list, \
                          std_cv_list, \
                          lstm_units=50, \
                          dropout_prob=0.5, \
                          optimizer='adam', \
                          epochs=1, \
                          batch_size=1):
    '''
    Train model, do prediction, scale back to original range and do evaluation
    Use LSTM here.
    Returns rmse, mape and predicted values
    Inputs
        x_train_scaled  : e.g. x_train_scaled.shape=(451, 9, 1). Here we are using the past 9 values to predict the next value
        y_train_scaled  : e.g. y_train_scaled.shape=(451, 1)
        x_cv_scaled     : use this to do predictions 
        y_cv            : actual value of the predictions
        mu_cv_list      : list of the means. Same length as x_scaled and y
        std_cv_list     : list of the std devs. Same length as x_scaled and y 
        lstm_units      : lstm param
        dropout_prob    : lstm param
        optimizer       : lstm param
        epochs          : lstm param
        batch_size      : lstm param
    Outputs
        rmse            : root mean square error
        mape            : mean absolute percentage error
        est             : predictions
    '''
    
    model = Sequential()
    model.add(LSTM(units=lstm_units, return_sequences=True, input_shape=(x_train_scaled.shape[1], 5)))
    model.add(Dropout(dropout_prob))
    model.add(LSTM(units=lstm_units))
    model.add(Dropout(dropout_prob))
    model.add(Dense(1))
    
    model.compile(loss='mean_squared_error', optimizer=optimizer)
    model.fit(x_train_scaled, y_train_scaled, epochs=epochs, batch_size=batch_size, verbose=0)
    
    #Do Prediction
    est_scaled = model.predict(x_cv_scaled)
    est = (est_scaled * np.array(std_cv_list).reshape(-1, 1)) + np.array(mu_cv_list).reshape(-1, 1)
    
    rmse = math.sqrt(mean_squared_error(y_cv, est))
    mape = get_mape(y_cv, est)
    
    return rmse, mape, est

# %%
def get_mape(y_true, y_pred):
    # Mean Absolute Percentage Error
    
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
rmse, mape, est = train_pred_eval_model(x_train_scaled, \
                                        y_train_scaled, \
                                        x_test_scaled, \
                                        y_test, \
                                        mu_test_list, \
                                        std_test_list, \
                                        lstm_units=128, \
                                        dropout_prob=1, \
                                        optimizer='nadam', \
                                        epochs=50, \
                                        batch_size=8)

# %%
rmse
# Out:
# 204.14953202312645

# %%
mape
# Out:
# 16.540538708364103

# %%
est
# Out:
# array([[1440.59681532],
#        [1441.14467541],
#        [1444.587492  ],
#        [1447.33854131],
#        [1447.74940636],
#        [1448.57654771],
#        [1448.67030991],
#        [1446.97315876],
#        [1444.57824414],
#        [1436.79366444],
#        [1427.2205076 ],
#        [1421.63560365],
#        [1417.39675396],
#        [1420.37643059],
#        [1419.23863496],
#        [1416.37149454],
#        [1417.00274913],
#        [1414.70835478],
#        [1418.56137571],
#        [1429.04542928]])

# %%
y_test
# Out:
# array([1243.32, 1239.09, 1246.74, 1248.3 , 1245.  , 1244.02, 1226.  ,
#        1231.23, 1196.98, 1189.06, 1211.44, 1218.2 , 1206.08, 1208.35,
#        1215.  , 1228.39, 1226.33, 1247.33, 1254.74, 1263.32])

# %%
# Plot adjusted close over time
rcParams['figure.figsize'] = 10, 8 # width 10, height 8

est_df = pd.DataFrame({'est': est.reshape(-1), 
                       'date': df[num_train:]['date']})

ax = train.plot(x='date', y='high', style='b-', grid=True)
ax = test.plot(x='date', y='high', style='g-', grid=True, ax=ax)
ax = est_df.plot(x='date', y='est', style='r-', grid=True, ax=ax)
ax.legend(['train', 'test', 'predictions'])
ax.set_xlabel("date")
ax.set_ylabel("USD")
# Out:
# Text(0, 0.5, 'USD')

# %%
test
# Out:
#          date     open     high      low  adj_close**  sentiments
